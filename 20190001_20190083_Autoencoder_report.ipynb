# %% [markdown]
# ### Autoencoder with size 32 x 32 x 3 with Noises

# %% [markdown]
# ![32_with_noises.png](attachment:32_with_noises.png)

# %% [markdown]
# ### Autoencoder with size 32 x 32 x 3 No Noises

# %% [markdown]
# ![32__no_noises.png](attachment:32__no_noises.png)

# %% [markdown]
# ### Autoencoder with size 64 x 64 x 3 With Noises

# %% [markdown]
# ![64_with_noises.png](attachment:64_with_noises.png)

# %% [markdown]
# ### Autoencoder with size 64 x 64 x 3 No Noises

# %% [markdown]
# ![64_no_noises.png](attachment:64_no_noises.png)

# %% [markdown]
# ![Screenshot%20from%202022-12-15%2000-06-13.png](attachment:Screenshot%20from%202022-12-15%2000-06-13.png)

# %% [markdown]
# ![Screenshot%20from%202022-12-15%2000-05-10.png](attachment:Screenshot%20from%202022-12-15%2000-05-10.png)

# %% [markdown]
# ![Screenshot%20from%202022-12-15%2000-08-22.png](attachment:Screenshot%20from%202022-12-15%2000-08-22.png)

# %% [markdown]
# ![Screenshot%20from%202022-12-15%2000-08-11.png](attachment:Screenshot%20from%202022-12-15%2000-08-11.png)
